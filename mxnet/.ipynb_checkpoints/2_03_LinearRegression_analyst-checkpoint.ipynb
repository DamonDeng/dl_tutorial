# %% [markdown]
# ## Linear Regression with symbol
#
# This sample constructs a simple linear regression model with symbol.
#
# To caculate the weights and bias of the following formula:
#
# x1*weight1 + x2*weight2 + bias = y

# %%
import mxnet as mx
import numpy as np

# %% [markdown]
# #### Generate sample data

# %%
l1_b1 = 8
l1_w1_1 = 3
l1_w1_2 = -5

l1_b2 =  3
l1_w2_1 = 4
l1_w2_2 = 5

l2_b1 = 3
l2_w1_1 = 4
l2_w1_2 = 7


sample_number = 100

x1 = np.random.rand(sample_number)
x2 = np.random.rand(sample_number)
noise = np.random.rand(sample_number)

x0_array = mx.nd.ones((sample_number,))
x1_array = mx.nd.array(x1)-0.5
x2_array = mx.nd.array(x2)-0.5
noise_array = mx.nd.array(noise)-0.5

x_data = mx.nd.concat(x0_array, x1_array, x2_array, dim=0).reshape((3,sample_number)).T
y_data = (x1_array*l1_w1_1 + x2_array*l1_w1_2 + l1_b1)*l2_w1_1 + (x1_array*l1_w2_1 + x2_array*l1_w2_2 + l1_b2)*l2_w1_2 + l2_b2 + noise_array*0.01

x_data[0:3].asnumpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-047b72fb05cb> in <module>()
#      24
#      25 x_data = mx.nd.concat(x0_array, x1_array, x2_array, dim=0).reshape((3,sample_number)).T
# ---> 26 y_data = (x1_array*l1_w1_1 + x2_array*l1_w1_2 + l1_b1)*l2_w1_1 + (x1_array*l1_w2_1 + x2_array*l1_w2_2 + l1_b2)*l2_w2_1 + l2_b2 + noise_array*0.01
#      27
#      28 x_data[0:3].asnumpy()
#
# NameError: name 'l2_w2_1' is not defined

# %% [markdown]
# #### Construct the model

# %%
input_x = mx.sym.Variable("input_x")
weight_x = mx.sym.Variable("weight_x")

input_y = mx.sym.Variable("input_y")

multiple_result = input_x * weight_x

sum_result = mx.sym.sum(multiple_result)

lost = mx.sym.sqrt(mx.sym.square(input_y - sum_result))

mx.viz.plot_network(symbol = lost)

# %% [markdown]
# #### Create the init weights
#
# weight_x_para is the placeholder of weights and bias
#
# weight_x_g is used to store gradience

# %%
weight_x_para = mx.nd.empty((3,))

weight_x_g = mx.nd.zeros((3,))

# %% [markdown]
# #### Train the model
#
# With for loop, we can call the forward and backward function again and again, to caculate the gradience of weights and then udpate the weights

# %%
for i in range(0,sample_number-1):
    exe = lost.bind(mx.cpu(), {"input_x":x_data[i],"weight_x":weight_x_para, "input_y":y_data[i]}, \
                args_grad = {'weight_x':weight_x_g})
    result = exe.forward(is_train=True)

    lost_value = result[0].asscalar()
    
    print "lost is",
    print lost_value
        
    exe.backward(result[0])
    
    weight_x_para = weight_x_para - weight_x_g
   
print "weight is: [b, w1, w2]"
print weight_x_para.asnumpy()
# Out:
# lost is 10.7273
# lost is 3.07162
# lost is 0.714501
# lost is 0.974802
# lost is 0.835795
# lost is 0.192519
# lost is 0.127239
# lost is 2.21703
# lost is 2.0939
# lost is 0.500047
# lost is 0.0547209
# lost is 0.134342
# lost is 0.510398
# lost is 0.488345
# lost is 0.11797
# lost is 0.227515
# lost is 0.01057
# lost is 0.145053
# lost is 0.0135956
# lost is 0.0802813
# lost is 0.0889316
# lost is 0.0235314
# lost is 0.0209942
# lost is 0.0423088
# lost is 0.08285
# lost is 0.0638762
# lost is 0.186296
# lost is 0.201573
# lost is 0.0775604
# lost is 0.0775948
# lost is 0.0283437
# lost is 0.0743608
# lost is 0.0442672
# lost is 0.017168
# lost is 0.0591178
# lost is 0.00614262
# lost is 0.0159416
# lost is 0.0746078
# lost is 0.109798
# lost is 0.142167
# lost is 0.0726728
# lost is 0.0330987
# lost is 0.000123024
# lost is 0.0631266
# lost is 0.0350161
# lost is 0.0454221
# lost is 0.0649319
# lost is 0.0877142
# lost is 0.0405293
# lost is 0.00843191
# lost is 0.0157571
# lost is 0.00818348
# lost is 0.0163875
# lost is 0.0182886
# lost is 0.00936842
# lost is 0.0202026
# lost is 0.0010767
# lost is 0.0147333
# lost is 0.000196934
# lost is 0.0104804
# lost is 0.0204525
# lost is 0.00539494
# lost is 0.00371265
# lost is 0.00473404
# lost is 0.00812483
# lost is 0.00760889
# lost is 0.00296593
# lost is 0.00245762
# lost is 0.00425434
# lost is 0.000255108
# lost is 0.0032897
# lost is 0.00397205
# lost is 0.00316286
# lost is 0.00375557
# lost is 0.00545025
# lost is 0.00305462
# lost is 0.000361919
# lost is 0.00553894
# lost is 0.00116682
# lost is 0.00210142
# lost is 0.00411987
# lost is 0.00199556
# lost is 0.00327969
# lost is 0.00373745
# lost is 0.00258589
# lost is 0.00105286
# lost is 0.00195789
# lost is 2.76566e-05
# lost is 0.00135899
# lost is 0.00473547
# lost is 0.000826836
# lost is 0.00339603
# lost is 0.00216389
# lost is 5.81741e-05
# lost is 0.00083065
# lost is 0.000412941
# lost is 0.00171089
# lost is 0.00661659
# lost is 0.00710392
# weight is: [b, w1, w2]
# [ 8.00303841  3.00125837 -4.99794292]
